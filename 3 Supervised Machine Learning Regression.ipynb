# %% [markdown]
# # Import libs

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# # Import data

# %%
df = pd.read_csv(r'/Users/r1121/Desktop/CF/11-2023Food Price Project/Data/Modified/food_price_global_varclean.csv', index_col = 0)

# %% [markdown]
# # Create a subset of data about eggs price in Europe (countries using euro)

# %%
df.head(15)
# Out:
#     _id                   country                                 food_type  \
# 0     1               Isle Of Man        Bread and other bakers wares (1kg)
# 1     2          Marshall Islands  Meat of chickens, fresh or chilled (1kg)
# 2     3               Timor-Leste                                Rice (1kg)
# 3     4              Burkina Faso                            Potatoes (1kg)
# 4     5                    Angola    Meat of cattle, fresh or chilled (1kg)
# 5     6              Burkina Faso               Lettuce and chicory (1head)
# 6     7                  Maldives  Meat of chickens, fresh or chilled (1kg)
# 7     8                   Lesotho                    Hen eggs in shell (12)
# 8     9                   Senegal                                Rice (1kg)
# 9    10                      Mali                    Hen eggs in shell (12)
# 10   11  Turks And Caicos Islands               Lettuce and chicory (1head)
# 11   12                   Liberia        Bread and other bakers wares (1kg)
# 12   13            Cayman Islands          Cheese, fresh or processed (1kg)
# 13   14                Martinique               Processed liquid milk (1lt)
# 14   15                  Maldives                            Potatoes (1kg)
#
#     baseline_local  local_price  variation_local local_currency  \
# 0             2.80         2.89             3.21              £
# 1             4.45         4.45             0.00              $
# 2             1.88         1.92             2.13              $
# 3           682.00       682.00             0.00            CFA
# 4            10.84        12.43            14.67              $
# 5           437.00       437.00             0.00            CFA
# 6            63.27        63.76             0.77             Rf
# 7            24.53        27.00            10.07              R
# 8           452.61       450.01            -0.57            CFA
# 9             1.52         1.86            22.37              $
# 10            2.50         2.50             0.00              $
# 11            4.75         5.38            13.26              $
# 12            7.20         7.32             1.67            KY$
# 13            0.93         0.93             0.00              €
# 14           20.92        20.66            -1.24             Rf
#
#       local_range        date
# 0       1.61-3.99  2020-07-19
# 1        4.41-4.5  2020-07-19
# 2          0.75-3  2020-07-19
# 3   600.01-763.99  2020-07-19
# 4      9.68-15.61  2020-07-19
# 5   200.00-674.00  2020-07-19
# 6     47.99-85.01  2020-07-19
# 7     24.00-30.00  2020-07-19
# 8   350.01-500.01  2020-07-19
# 9       1.01-2.04  2020-07-19
# 10      2.00-3.00  2020-07-19
# 11      3.31-8.82  2020-07-19
# 12        6-10.01  2020-07-19
# 13      0.78-1.08  2020-07-19
# 14          20-22  2020-07-19

# %%
df.shape
# Out:
# (49807, 9)

# %% [markdown]
# ## Due to the scale of our client and perishability of eggs, we will focus on European countries using euro. And since client is looking for suppliers of eggs, we will use data about eggs price.

# %%
# creat a subset about eggs in Europe.

df_ee = df.loc[(df['food_type']=='Hen eggs in shell (12)')&(df['local_currency']=='€')]

# %%
df_ee.head(10)
# Out:
#        _id     country               food_type  baseline_local  local_price  \
# 217    218  Martinique  Hen eggs in shell (12)            3.94         4.25
# 416    417     Andorra  Hen eggs in shell (12)            2.35         2.52
# 792    793  Martinique  Hen eggs in shell (12)            3.94         3.94
# 819    820     Andorra  Hen eggs in shell (12)            2.35         2.35
# 928    929  Martinique  Hen eggs in shell (12)            3.94         4.25
# 1013  1014  San Marino  Hen eggs in shell (12)            3.78         2.63
# 1337  1338     Andorra  Hen eggs in shell (12)            2.35         2.52
# 1613  1614  Martinique  Hen eggs in shell (12)            3.94         4.25
# 1679  1680     Andorra  Hen eggs in shell (12)            2.35         2.52
# 2291  2292  Martinique  Hen eggs in shell (12)            3.94         4.25
#
#       variation_local local_currency local_range        date
# 217              7.87              €   2.97-4.85  2020-07-19
# 416              7.23              €   1.50-3.60  2020-07-19
# 792              0.00              €   2.97-4.85  2020-04-05
# 819              0.00              €   1.50-3.60  2020-04-05
# 928              7.87              €   2.97-4.85  2021-04-04
# 1013           -30.42              €   2.00-3.00  2021-04-04
# 1337             7.23              €   1.50-3.60  2021-04-04
# 1613             7.87              €   2.97-4.85  2020-07-05
# 1679             7.23              €   1.50-3.60  2020-07-05
# 2291             7.87              €   2.97-4.85  2020-08-16

# %%
df_ee.shape
# Out:
# (477, 9)

# %% [markdown]
# # Clean the new data set

# %% [markdown]
# ## Missing value

# %%
df_ee.isnull().sum()
# Out:
# _id                0
# country            0
# food_type          0
# baseline_local     0
# local_price        0
# variation_local    0
# local_currency     0
# local_range        0
# date               0
# dtype: int64

# %% [markdown]
# ## Duplicates

# %%
dup = df_ee.duplicated()

# %%
dup.shape
# Out:
# (477,)

# %% [markdown]
# ## Mixed types

# %%
for col in df_ee.columns.tolist():
  weird = (df_ee[[col]].applymap(type) != df_ee[[col]].iloc[0].apply(type)).any(axis = 1)
if len (df_ee[weird]) > 0:
    print (col)
else:
    print ('No mixed types data')
# Out:
# No mixed types data

# %% [markdown]
# ## Extreme values check

# %%
# create a distribution plot for local price to check extreme values
sns.distplot(df_ee['local_price'], bins=25)
# Out:
# /Users/r1121/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='local_price', ylabel='Density'>

# %%
df_ee['local_price'].mean()
# Out:
# 2.476100628930823

# %%
df_ee['local_price'].median()
# Out:
# 2.48

# %%
df_ee['local_price'].min()
# Out:
# 1.42

# %%
df_ee['local_price'].max()
# Out:
# 4.25

# %%
# create a distribution plot for price variation to check extreme values
sns.distplot(df_ee['variation_local'], bins=25)
# Out:
# /Users/r1121/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='variation_local', ylabel='Density'>

# %%
df_ee['variation_local'].mean()
# Out:
# 1.632851153039831

# %%
df_ee['variation_local'].median()
# Out:
# 4.3

# %%
df_ee['variation_local'].min()
# Out:
# -93.94

# %% [markdown]
# From plot above, we can see there is an observation out of the bell-shaped distribution. Since it makes the statistics skewed greatly, it shall be considered as 'outlier'.

# %%
# creat a scatterplot to see the outliers.

sns.scatterplot(x='variation_local', y='variation_local', data = df_ee)
# Out:
# <AxesSubplot:xlabel='variation_local', ylabel='variation_local'>

# %%
# check the number of outliers.
df_ee_ex = df_ee[df_ee['variation_local'] < -40]
df_ee_ex.shape
# Out:
# (15, 9)

# %%
df_ee_ex.head(15)
# Out:
#          _id     country               food_type  baseline_local  local_price  \
# 44127  44128  Seychelles  Hen eggs in shell (12)           33.35         2.16
# 44154  44155  Seychelles  Hen eggs in shell (12)           33.35         2.02
# 44165  44166  Seychelles  Hen eggs in shell (12)           33.35         2.16
# 44177  44178  Seychelles  Hen eggs in shell (12)           33.35         2.16
# 44194  44195  Seychelles  Hen eggs in shell (12)           33.35         2.16
# 44205  44206  Seychelles  Hen eggs in shell (12)           33.35         2.16
# 44219  44220  Seychelles  Hen eggs in shell (12)           33.35         2.16
# 44235  44236  Seychelles  Hen eggs in shell (12)           33.35         2.02
# 44246  44247  Seychelles  Hen eggs in shell (12)           33.35         2.16
# 44254  44255  Seychelles  Hen eggs in shell (12)           33.35         2.16
# 44281  44282  Seychelles  Hen eggs in shell (12)           33.35         2.16
# 44286  44287  Seychelles  Hen eggs in shell (12)           33.35         2.16
# 44303  44304  Seychelles  Hen eggs in shell (12)           33.35         2.02
# 44328  44329  Seychelles  Hen eggs in shell (12)           33.35         2.16
# 44347  44348  Seychelles  Hen eggs in shell (12)           33.35         2.16
#
#        variation_local local_currency local_range        date
# 44127           -93.52              €   1.30-2.76  2020-07-19
# 44154           -93.94              €   1.30-2.76  2021-04-04
# 44165           -93.52              €   1.30-2.76  2020-07-05
# 44177           -93.52              €   1.30-2.76  2020-08-16
# 44194           -93.52              €   1.30-2.76  2020-06-28
# 44205           -93.52              €   1.30-2.76  2020-11-08
# 44219           -93.52              €   1.30-2.76  2021-01-10
# 44235           -93.94              €   1.30-2.76  2021-03-07
# 44246           -93.52              €   1.30-2.76  2020-09-27
# 44254           -93.52              €   1.30-2.76  2020-10-18
# 44281           -93.52              €   1.30-2.76  2020-08-02
# 44286           -93.52              €   1.30-2.76  2020-09-13
# 44303           -93.94              €   1.30-2.76  2021-04-11
# 44328           -93.52              €   1.30-2.76  2020-11-15
# 44347           -93.52              €   1.30-2.76  2020-06-14

# %%
# remove the outlier
df_ee_no_ex = df_ee[df_ee['variation_local']>= -40]
df_ee_no_ex.shape
# Out:
# (462, 9)

# %%
# export the new dataset about eggs price in Europe
df_ee_no_ex.to_csv(r'/Users/r1121/Desktop/CF/11-2023Food Price Project/Data/Modified/egg_price_eu.csv')

# %% [markdown]
# ## Scatterplot between price and house age

# %%
df_ee_no_ex.plot(y='local_price', x='baseline_local', style='o')
plt.title('Baseline price vs Local price')
plt.ylabel('local_price')
# Out:
# Text(0, 0.5, 'local_price')

# %% [markdown]
# Hypothesis: Local price has a positive relationship with baseline price. In other words, lower baseline pirce, lower local price.

# %% [markdown]
# # Machine learning- Linear regression

# %%
# Reshape the variables into NumPy arrays and put them into separate objects.
X = df_ee_no_ex['baseline_local'].values.reshape(-1,1)
y = df_ee_no_ex['local_price'].values.reshape(-1,1)

# %%
X
# Out:
# array([[3.94],
#        [2.35],
#        [3.94],
#        [2.35],
#        [3.94],
#        [3.78],
#        [2.35],
#        [3.94],
#        [2.35],
#        [3.94],
#        [2.35],
#        [3.94],
#        [2.35],
#        [3.78],
#        [3.94],
#        [2.35],
#        [2.35],
#        [3.94],
#        [3.78],
#        [2.35],
#        [3.94],
#        [3.78],
#        [2.35],
#        [3.94],
#        [3.78],
#        [2.35],
#        [3.78],
#        [3.94],
#        [3.94],
#        [2.35],
#        [2.35],
#        [3.94],
#        [3.78],
#        [3.78],
#        [3.94],
#        [2.35],
#        [2.35],
#        [3.94],
#        [3.78],
#        [2.35],
#        [3.94],
#        [2.35],
#        [3.94],
#        [2.35],
#        [3.94],
#        [2.25],
#        [2.25],
#        [2.25],
#        [2.25],
#        [2.25],
#        [2.25],
#        [2.25],
#        [2.25],
#        [2.25],
#        [2.25],
#        [2.25],
#        [2.25],
#        [2.25],
#        [2.25],
#        [2.25],
#        [2.25],
#        [2.25],
#        [2.25],
#        [2.69],
#        [2.69],
#        [2.69],
#        [2.69],
#        [2.69],
#        [2.69],
#        [2.69],
#        [2.69],
#        [2.69],
#        [2.69],
#        [2.69],
#        [2.69],
#        [2.69],
#        [2.69],
#        [2.69],
#        [2.69],
#        [2.69],
#        [2.69],
#        [2.51],
#        [2.51],
#        [2.51],
#        [2.51],
#        [2.51],
#        [2.51],
#        [2.51],
#        [2.51],
#        [2.51],
#        [2.51],
#        [2.51],
#        [2.51],
#        [2.51],
#        [2.51],
#        [2.51],
#        [2.51],
#        [2.51],
#        [2.51],
#        [2.61],
#        [2.61],
#        [2.61],
#        [2.61],
#        [2.61],
#        [2.61],
#        [2.61],
#        [2.61],
#        [2.61],
#        [2.61],
#        [2.61],
#        [2.61],
#        [2.61],
#        [2.61],
#        [2.61],
#        [2.61],
#        [2.61],
#        [2.61],
#        [1.84],
#        [1.84],
#        [1.84],
#        [1.84],
#        [1.84],
#        [1.84],
#        [1.84],
#        [1.84],
#        [1.84],
#        [1.84],
#        [1.84],
#        [1.84],
#        [1.84],
#        [1.84],
#        [1.84],
#        [1.84],
#        [1.84],
#        [1.84],
#        [1.62],
#        [1.62],
#        [1.62],
#        [1.62],
#        [1.62],
#        [1.62],
#        [1.62],
#        [1.62],
#        [1.62],
#        [1.62],
#        [1.62],
#        [1.62],
#        [1.62],
#        [1.62],
#        [1.62],
#        [1.62],
#        [1.62],
#        [1.62],
#        [1.62],
#        [1.51],
#        [1.51],
#        [1.51],
#        [1.51],
#        [1.51],
#        [1.51],
#        [1.51],
#        [1.51],
#        [1.51],
#        [1.51],
#        [1.51],
#        [1.51],
#        [1.51],
#        [1.51],
#        [1.51],
#        [1.51],
#        [1.51],
#        [1.51],
#        [1.86],
#        [1.86],
#        [1.86],
#        [1.86],
#        [1.86],
#        [1.86],
#        [1.86],
#        [1.86],
#        [1.86],
#        [1.86],
#        [1.86],
#        [1.86],
#        [1.86],
#        [1.86],
#        [1.86],
#        [1.86],
#        [1.86],
#        [1.86],
#        [2.87],
#        [2.87],
#        [2.87],
#        [2.87],
#        [2.87],
#        [2.87],
#        [2.87],
#        [2.87],
#        [2.87],
#        [2.87],
#        [2.87],
#        [2.87],
#        [2.87],
#        [2.87],
#        [2.87],
#        [2.87],
#        [2.87],
#        [2.87],
#        [2.94],
#        [2.94],
#        [2.94],
#        [2.94],
#        [2.94],
#        [2.94],
#        [2.94],
#        [2.94],
#        [2.94],
#        [2.94],
#        [2.94],
#        [2.94],
#        [2.94],
#        [2.94],
#        [2.94],
#        [2.94],
#        [2.94],
#        [2.94],
#        [2.67],
#        [2.67],
#        [2.67],
#        [2.67],
#        [2.67],
#        [2.67],
#        [2.67],
#        [2.67],
#        [2.67],
#        [2.67],
#        [2.67],
#        [2.67],
#        [2.67],
#        [2.67],
#        [2.67],
#        [2.67],
#        [2.67],
#        [2.67],
#        [2.6 ],
#        [2.6 ],
#        [2.6 ],
#        [2.6 ],
#        [2.6 ],
#        [2.6 ],
#        [2.6 ],
#        [2.6 ],
#        [2.6 ],
#        [2.6 ],
#        [2.6 ],
#        [2.6 ],
#        [2.6 ],
#        [2.6 ],
#        [2.6 ],
#        [2.6 ],
#        [2.6 ],
#        [2.6 ],
#        [1.46],
#        [1.46],
#        [1.46],
#        [1.46],
#        [1.46],
#        [1.46],
#        [1.46],
#        [1.46],
#        [1.46],
#        [1.46],
#        [1.46],
#        [1.46],
#        [1.46],
#        [1.46],
#        [1.46],
#        [1.46],
#        [1.46],
#        [1.46],
#        [3.76],
#        [3.76],
#        [3.76],
#        [3.76],
#        [3.76],
#        [3.76],
#        [3.76],
#        [3.76],
#        [3.76],
#        [3.76],
#        [3.76],
#        [3.76],
#        [3.76],
#        [3.76],
#        [3.76],
#        [3.76],
#        [3.76],
#        [3.76],
#        [1.64],
#        [1.64],
#        [1.64],
#        [1.64],
#        [1.64],
#        [1.64],
#        [1.64],
#        [1.64],
#        [1.64],
#        [1.64],
#        [1.64],
#        [1.64],
#        [1.64],
#        [1.64],
#        [1.64],
#        [1.64],
#        [1.64],
#        [1.64],
#        [1.64],
#        [2.8 ],
#        [2.8 ],
#        [2.8 ],
#        [2.8 ],
#        [2.8 ],
#        [2.8 ],
#        [2.8 ],
#        [2.8 ],
#        [2.8 ],
#        [2.8 ],
#        [2.8 ],
#        [2.8 ],
#        [2.8 ],
#        [2.8 ],
#        [2.8 ],
#        [2.8 ],
#        [2.8 ],
#        [2.8 ],
#        [2.41],
#        [2.41],
#        [2.41],
#        [2.41],
#        [2.41],
#        [2.41],
#        [2.41],
#        [2.41],
#        [2.41],
#        [2.41],
#        [2.41],
#        [2.41],
#        [2.41],
#        [2.41],
#        [2.41],
#        [2.41],
#        [2.41],
#        [2.41],
#        [1.41],
#        [1.41],
#        [1.41],
#        [1.41],
#        [1.41],
#        [1.41],
#        [1.41],
#        [1.41],
#        [1.41],
#        [1.41],
#        [1.41],
#        [1.41],
#        [1.41],
#        [1.41],
#        [1.41],
#        [1.41],
#        [1.41],
#        [1.41],
#        [2.29],
#        [2.29],
#        [2.29],
#        [2.29],
#        [2.29],
#        [2.29],
#        [2.29],
#        [2.29],
#        [2.29],
#        [2.29],
#        [2.29],
#        [2.29],
#        [2.29],
#        [2.29],
#        [2.29],
#        [2.29],
#        [2.29],
#        [2.29],
#        [1.69],
#        [1.69],
#        [1.69],
#        [1.69],
#        [1.69],
#        [1.69],
#        [1.69],
#        [1.69],
#        [1.69],
#        [1.69],
#        [1.69],
#        [1.69],
#        [1.69],
#        [1.69],
#        [1.69],
#        [1.69],
#        [1.69],
#        [1.69],
#        [1.69],
#        [3.25],
#        [3.25],
#        [3.25],
#        [3.25],
#        [3.25],
#        [3.25],
#        [3.25],
#        [3.25],
#        [3.25],
#        [3.25],
#        [3.25],
#        [3.25],
#        [3.25],
#        [3.25],
#        [3.25],
#        [3.25],
#        [3.25],
#        [3.25],
#        [1.84],
#        [1.84],
#        [1.84],
#        [1.84],
#        [1.84],
#        [1.84],
#        [1.84],
#        [1.84],
#        [1.84],
#        [1.84],
#        [1.84],
#        [1.84],
#        [1.84],
#        [1.84],
#        [1.84],
#        [1.84],
#        [1.84],
#        [1.84],
#        [2.15],
#        [2.15],
#        [2.15],
#        [2.15],
#        [2.15],
#        [2.15],
#        [2.15],
#        [2.15],
#        [2.15],
#        [2.15],
#        [2.15],
#        [2.15],
#        [2.15],
#        [2.15],
#        [2.15],
#        [2.15],
#        [2.15],
#        [2.15]])

# %%
y
# Out:
# array([[4.25],
#        [2.52],
#        [3.94],
#        [2.35],
#        [4.25],
#        [2.63],
#        [2.52],
#        [4.25],
#        [2.52],
#        [4.25],
#        [2.52],
#        [4.2 ],
#        [2.52],
#        [2.94],
#        [4.25],
#        [2.52],
#        [2.52],
#        [4.25],
#        [2.94],
#        [2.52],
#        [4.25],
#        [2.63],
#        [2.52],
#        [4.25],
#        [2.94],
#        [2.52],
#        [2.94],
#        [4.25],
#        [4.25],
#        [2.52],
#        [2.52],
#        [4.25],
#        [2.94],
#        [2.63],
#        [4.25],
#        [2.52],
#        [2.35],
#        [3.94],
#        [2.94],
#        [2.52],
#        [4.25],
#        [2.49],
#        [3.94],
#        [2.35],
#        [3.94],
#        [2.48],
#        [2.48],
#        [2.48],
#        [2.48],
#        [2.48],
#        [2.48],
#        [2.48],
#        [2.48],
#        [2.48],
#        [2.61],
#        [2.48],
#        [2.48],
#        [2.55],
#        [2.48],
#        [2.48],
#        [2.48],
#        [2.48],
#        [2.48],
#        [2.81],
#        [2.74],
#        [2.97],
#        [2.76],
#        [2.81],
#        [2.75],
#        [2.83],
#        [2.82],
#        [2.93],
#        [2.83],
#        [2.86],
#        [2.8 ],
#        [2.82],
#        [2.98],
#        [2.79],
#        [2.84],
#        [2.73],
#        [2.78],
#        [2.49],
#        [2.54],
#        [2.59],
#        [2.49],
#        [2.52],
#        [2.49],
#        [2.49],
#        [2.57],
#        [2.57],
#        [2.48],
#        [2.49],
#        [2.51],
#        [2.51],
#        [2.6 ],
#        [2.52],
#        [2.5 ],
#        [2.51],
#        [2.52],
#        [2.66],
#        [2.62],
#        [2.6 ],
#        [2.64],
#        [2.67],
#        [2.65],
#        [2.72],
#        [2.66],
#        [2.65],
#        [2.71],
#        [2.7 ],
#        [2.67],
#        [2.7 ],
#        [2.61],
#        [2.67],
#        [2.72],
#        [2.67],
#        [2.58],
#        [2.  ],
#        [1.9 ],
#        [2.24],
#        [1.99],
#        [2.01],
#        [1.94],
#        [2.23],
#        [2.23],
#        [2.26],
#        [2.22],
#        [2.23],
#        [2.01],
#        [2.2 ],
#        [2.25],
#        [1.91],
#        [2.23],
#        [1.92],
#        [1.91],
#        [1.77],
#        [1.72],
#        [1.86],
#        [1.77],
#        [1.77],
#        [1.77],
#        [1.83],
#        [1.86],
#        [1.87],
#        [1.79],
#        [1.82],
#        [1.76],
#        [1.78],
#        [1.86],
#        [1.74],
#        [1.83],
#        [1.77],
#        [1.74],
#        [1.73],
#        [1.53],
#        [1.55],
#        [1.46],
#        [1.54],
#        [1.51],
#        [1.54],
#        [1.49],
#        [1.49],
#        [1.47],
#        [1.5 ],
#        [1.46],
#        [1.53],
#        [1.51],
#        [1.46],
#        [1.52],
#        [1.49],
#        [1.54],
#        [1.52],
#        [2.03],
#        [1.95],
#        [2.07],
#        [2.03],
#        [2.06],
#        [2.01],
#        [2.05],
#        [2.04],
#        [2.09],
#        [2.04],
#        [2.06],
#        [2.03],
#        [2.04],
#        [2.07],
#        [2.01],
#        [2.05],
#        [2.01],
#        [2.01],
#        [3.  ],
#        [2.92],
#        [2.97],
#        [3.  ],
#        [3.01],
#        [2.99],
#        [3.  ],
#        [2.97],
#        [2.98],
#        [3.01],
#        [3.01],
#        [3.01],
#        [3.02],
#        [2.98],
#        [2.96],
#        [3.  ],
#        [2.98],
#        [2.95],
#        [3.1 ],
#        [3.03],
#        [3.14],
#        [3.08],
#        [3.13],
#        [3.08],
#        [3.14],
#        [3.18],
#        [3.17],
#        [3.13],
#        [3.14],
#        [3.11],
#        [3.11],
#        [3.14],
#        [3.07],
#        [3.14],
#        [3.06],
#        [3.05],
#        [2.71],
#        [2.68],
#        [2.9 ],
#        [2.71],
#        [2.77],
#        [2.7 ],
#        [2.8 ],
#        [2.83],
#        [2.85],
#        [2.78],
#        [2.8 ],
#        [2.74],
#        [2.79],
#        [2.91],
#        [2.72],
#        [2.79],
#        [2.69],
#        [2.69],
#        [2.76],
#        [2.71],
#        [2.8 ],
#        [2.76],
#        [2.76],
#        [2.75],
#        [2.77],
#        [2.79],
#        [2.81],
#        [2.77],
#        [2.77],
#        [2.77],
#        [2.77],
#        [2.8 ],
#        [2.74],
#        [2.78],
#        [2.75],
#        [2.73],
#        [1.47],
#        [1.45],
#        [1.45],
#        [1.47],
#        [1.49],
#        [1.49],
#        [1.47],
#        [1.42],
#        [1.43],
#        [1.48],
#        [1.46],
#        [1.48],
#        [1.5 ],
#        [1.43],
#        [1.44],
#        [1.46],
#        [1.5 ],
#        [1.45],
#        [4.  ],
#        [3.85],
#        [3.71],
#        [3.85],
#        [3.78],
#        [3.85],
#        [3.8 ],
#        [3.65],
#        [3.71],
#        [3.94],
#        [3.9 ],
#        [3.87],
#        [4.  ],
#        [3.71],
#        [3.87],
#        [3.8 ],
#        [3.85],
#        [3.87],
#        [1.75],
#        [1.66],
#        [1.82],
#        [1.76],
#        [1.79],
#        [1.75],
#        [1.79],
#        [1.79],
#        [1.83],
#        [1.82],
#        [1.8 ],
#        [1.77],
#        [1.79],
#        [1.82],
#        [1.72],
#        [1.79],
#        [1.74],
#        [1.69],
#        [1.69],
#        [3.03],
#        [3.03],
#        [3.03],
#        [3.03],
#        [3.03],
#        [3.03],
#        [3.03],
#        [3.03],
#        [3.03],
#        [3.03],
#        [3.03],
#        [3.03],
#        [3.03],
#        [3.03],
#        [3.03],
#        [3.03],
#        [3.03],
#        [3.03],
#        [2.47],
#        [2.46],
#        [2.58],
#        [2.47],
#        [2.46],
#        [2.47],
#        [2.46],
#        [2.46],
#        [2.53],
#        [2.46],
#        [2.46],
#        [2.47],
#        [2.46],
#        [2.56],
#        [2.45],
#        [2.45],
#        [2.49],
#        [2.45],
#        [1.5 ],
#        [1.45],
#        [1.53],
#        [1.48],
#        [1.53],
#        [1.48],
#        [1.53],
#        [1.53],
#        [1.52],
#        [1.53],
#        [1.52],
#        [1.52],
#        [1.51],
#        [1.53],
#        [1.45],
#        [1.53],
#        [1.47],
#        [1.46],
#        [2.4 ],
#        [2.35],
#        [2.12],
#        [2.39],
#        [2.34],
#        [2.39],
#        [2.12],
#        [2.13],
#        [2.09],
#        [2.11],
#        [2.11],
#        [2.4 ],
#        [2.37],
#        [2.12],
#        [2.38],
#        [2.12],
#        [2.39],
#        [2.37],
#        [1.75],
#        [1.73],
#        [1.77],
#        [1.73],
#        [1.74],
#        [1.72],
#        [1.76],
#        [1.78],
#        [1.77],
#        [1.74],
#        [1.76],
#        [1.75],
#        [1.74],
#        [1.77],
#        [1.7 ],
#        [1.76],
#        [1.72],
#        [1.7 ],
#        [1.71],
#        [3.83],
#        [3.33],
#        [3.64],
#        [3.83],
#        [3.83],
#        [3.83],
#        [3.83],
#        [3.75],
#        [3.64],
#        [3.83],
#        [3.83],
#        [3.83],
#        [3.83],
#        [3.64],
#        [3.83],
#        [3.83],
#        [3.83],
#        [3.75],
#        [1.89],
#        [1.85],
#        [1.89],
#        [1.89],
#        [1.91],
#        [1.87],
#        [1.89],
#        [1.87],
#        [1.88],
#        [1.89],
#        [1.9 ],
#        [1.9 ],
#        [1.89],
#        [1.89],
#        [1.86],
#        [1.89],
#        [1.87],
#        [1.86],
#        [2.2 ],
#        [2.17],
#        [2.13],
#        [2.18],
#        [2.2 ],
#        [2.2 ],
#        [2.19],
#        [2.13],
#        [2.14],
#        [2.18],
#        [2.19],
#        [2.2 ],
#        [2.15],
#        [2.13],
#        [2.2 ],
#        [2.19],
#        [2.18],
#        [2.19]])

# %%
# Split X, y array into training and test set.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=0)

# %%
# create a regression object.
regression = LinearRegression()

# %%
# Fit the training set into the regression object.
regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predict y with X_test
y_predicted =regression.predict(X_test)

# %%
# Create a plot that shows the regression line from the model on the test set.
plt.scatter(X_test, y_test)
plt.plot(X_test, y_predicted, color='red')
plt.xlabel('Baseline price')
plt.ylabel('Local price')
plt.title('Baseline price vs Local price')
# Out:
# Text(0.5, 1.0, 'Baseline price vs Local price')

# %%
# Check the model summary statistics of the predicted results.
rmse = mean_squared_error(y_test, y_predicted)
r2 = r2_score(y_test, y_predicted)

# %%
print('Slope:', regression.coef_)
print('Root mean squared error:', rmse)
print('R2 score:', r2)
# Out:
# Slope: [[0.99954015]]
# Root mean squared error: 0.04796228604465339
# R2 score: 0.911032217629022

# %% [markdown]
# According r2 score, we know that this linear reggression model is a great fit in this situation at all. Over 90% of data points fit in this model.

# %%
# Compare y_test and y_predicted
comp_test_predicted = pd.DataFrame({'Actual':y_test.flatten(), 'Predicted':y_predicted.flatten()})

# %%
comp_test_predicted.head(20)
# Out:
#     Actual  Predicted
# 0     2.67   2.714600
# 1     2.63   3.884062
# 2     2.84   2.794563
# 3     1.90   1.944954
# 4     3.05   3.044449
# 5     3.83   3.354306
# 6     2.34   2.394747
# 7     2.93   2.794563
# 8     2.48   2.614646
# 9     2.45   2.514692
# 10    2.23   1.944954
# 11    2.62   2.714600
# 12    2.46   2.514692
# 13    1.74   1.795023
# 14    1.53   1.615106
# 15    2.03   1.964945
# 16    3.03   2.904513
# 17    2.52   2.454720
# 18    1.75   1.745046
# 19    1.85   1.944954

# %% [markdown]
# Ideally, local food price ought to be very close to its baseline price. Value of the food products impacts their prices. In the healthy economy countries, we could consider choosing suppliers by local baseline price.
